# %% [markdown]
# ## OpenStreetMap Data for China
#
# The OpenStreetMap (OSM) Data for China, provided by Geofabrik GmbH through
# https://download.geofabrik.de/asia/china.html￼, is an openly accessible and regularly updated geospatial dataset derived from the global OpenStreetMap project. It offers comprehensive vector data describing China’s road network, land use, buildings, natural features, and a wide range of additional geographic entities. The dataset is widely used in urban studies, transportation research, and spatial econometrics due to its free access, extensive coverage and high level of detail in metropolitan regions.

# %%
# %pip install geopandas networkx shapely pyproj
# Out:
# Collecting geopandas
#   Using cached geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting networkx
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting shapely
#   Using cached shapely-2.1.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.8 kB)
# Collecting pyproj
#   Using cached pyproj-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting numpy>=1.24 (from geopandas)
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Using cached pyogrio-0.12.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: packaging in /home/zyk/anaconda3/envs/nshs25/lib/python3.10/site-packages (from geopandas) (25.0)
# Collecting pandas>=2.0.0 (from geopandas)
#   Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting certifi (from pyproj)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zyk/anaconda3/envs/nshs25/lib/python3.10/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=2.0.0->geopandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in /home/zyk/.local/lib/python3.10/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/zyk/anaconda3/envs/nshs25/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Using cached geopandas-1.1.1-py3-none-any.whl (338 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached shapely-2.1.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.1 MB)
# Using cached pyproj-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# Using cached pyogrio-0.12.0-cp310-cp310-manylinux_2_28_x86_64.whl (32.4 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Installing collected packages: pytz, numpy, networkx, certifi, shapely, pyproj, pyogrio, pandas, geopandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [geopandas]/9 [geopandas]
# Successfully installed certifi-2025.11.12 geopandas-1.1.1 networkx-3.4.2 numpy-2.2.6 pandas-2.3.3 pyogrio-0.12.0 pyproj-3.7.1 pytz-2025.2 shapely-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

roads = gpd.read_file("data/beijing-251127-free/gis_osm_roads_free_1.shp")
roads.head(10)
# Out:
#     osm_id  code       fclass   name   ref oneway  maxspeed  layer bridge  \
# 0  4231222  5114    secondary   None  None      F         0      0      F
# 1  4231223  5114    secondary  广场东侧路  None      F        70      0      F
# 2  4263917  5112        trunk    复兴路  G108      F         0      0      F
# 3  4263918  5115     tertiary  兵部洼胡同  None      B         0      0      F
# 4  4484480  5115     tertiary   军博西路  None      F         0      0      F
# 5  4484630  5112        trunk   东长安街  None      F         0      0      F
# 6  4493469  5114    secondary   南新华街  None      F         0      0      F
# 7  4822336  5115     tertiary    慧忠路  None      F         0      0      F
# 8  4822342  5122  residential   None  None      B         0      0      F
# 9  4822362  5112        trunk  北四环中路  None      F        80      0      F
#
#   tunnel                                           geometry
# 0      F  LINESTRING (116.38943 39.90626, 116.38945 39.9...
# 1      F  LINESTRING (116.39346 39.89888, 116.39344 39.8...
# 2      F  LINESTRING (116.3251 39.9063, 116.32474 39.906...
# 3      F  LINESTRING (116.38186 39.89886, 116.38187 39.8...
# 4      F  LINESTRING (116.31552 39.9065, 116.31558 39.90...
# 5      F  LINESTRING (116.41165 39.90694, 116.41152 39.9...
# 6      F  LINESTRING (116.37797 39.89737, 116.37803 39.8...
# 7      F  LINESTRING (116.39472 39.99325, 116.39496 39.9...
# 8      F  LINESTRING (116.39718 39.99328, 116.39722 39.9...
# 9      F  LINESTRING (116.36406 39.98593, 116.36562 39.9...

# %%
import geopandas as gpd

roads = gpd.read_file("data/beijing-251127-free/gis_osm_railways_free_1.shp")
roads.head(10)
# Out:
#      osm_id  code  fclass     name  layer bridge tunnel  \
# 0   9853311  6101    rail      京哈线      1      T      F
# 1   9853512  6101    rail     None      0      F      F
# 2  23426905  6101    rail     None      0      F      F
# 3  24818659  6103  subway  北京地铁1号线     -4      F      T
# 4  24818783  6101    rail  京沪京哈联络线      0      F      F
# 5  24834552  6101    rail      西长线      0      F      F
# 6  24850764  6101    rail     None      0      F      F
# 7  24850768  6101    rail     None      0      F      F
# 8  24851159  6101    rail      京沪线     -3      F      T
# 9  24851370  6101    rail      京沪线      0      T      F
#
#                                             geometry
# 0  LINESTRING (116.42969 39.90063, 116.43042 39.9...
# 1  LINESTRING (116.49008 39.90079, 116.49046 39.9...
# 2  LINESTRING (116.49125 39.90079, 116.49227 39.9...
# 3  LINESTRING (116.16492 39.93855, 116.16533 39.9...
# 4  LINESTRING (116.43486 39.89624, 116.43489 39.8...
# 5  LINESTRING (116.31895 39.8942, 116.31531 39.8942)
# 6  LINESTRING (116.4238 39.90166, 116.42407 39.90...
# 7  LINESTRING (116.42405 39.90054, 116.4234 39.90...
# 8  LINESTRING (116.41369 39.89983, 116.41384 39.8...
# 9  LINESTRING (116.42967 39.90054, 116.43143 39.9...

# %%
import geopandas as gpd

roads = gpd.read_file("data/beijing-251127-free/gis_osm_transport_free_1.shp")
roads.head(10)
# Out:
#       osm_id  code           fclass   name                    geometry
# 0   32618803  5621         bus_stop    铸钟厂  POINT (116.38547 39.94023)
# 1   32618809  5621         bus_stop  德内甘水桥  POINT (116.38149 39.94313)
# 2  124205138  5601  railway_station   北京丰台     POINT (116.29534 39.85)
# 3  240421944  5621         bus_stop  海淀黄庄南   POINT (116.3126 39.97227)
# 4  268389725  5621         bus_stop   大石桥北   POINT (116.32224 40.0122)
# 5  269704764  5661   ferry_terminal   None  POINT (116.38099 39.92879)
# 6  269704765  5661   ferry_terminal   None  POINT (116.38284 39.92549)
# 7  269996666  5601  railway_station     北京  POINT (116.42101 39.90112)
# 8  281923785  5621         bus_stop  地铁上地站  POINT (116.31433 40.03042)
# 9  286278882  5621         bus_stop  安宁庄西路  POINT (116.31728 40.03823)
